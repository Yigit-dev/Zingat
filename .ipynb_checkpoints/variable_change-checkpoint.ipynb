# %%
import pandas as pd
df = pd.read_csv("./datasets/zingat_usecase_testset_null.csv")
df.head()
# Out:
#         tarih                         path odasayısı  brütm²  netm² emlaktipi  \
# 0  2020-04-20        İzmir/Konak/Güzelyalı       4+1   165.0  155.0     Daire
# 1  2020-04-20           İzmir/Ödemiş/İnönü       2+1   130.0  120.0     Daire
# 2  2020-04-20     İzmir/Karşıyaka/Örnekköy       3+1   182.0  153.0     Daire
# 3  2020-04-20           İzmir/Ödemiş/İnönü       2+1   130.0  120.0     Daire
# 4  2020-04-20  İstanbul/Beylikdüzü/Kavaklı       3+1   125.0  120.0     Daire
#
#       binayaşı bulunduğukat binadakikatsayısı        isıtmatipi  ...  \
# 0  31-35 arası            6                 7  Kombi (Doğalgaz)  ...
# 1   6-10 arası            2                 2             Klima  ...
# 2            0            7       10-20 arası     Yerden Isıtma  ...
# 3   6-10 arası            2                 2             Klima  ...
# 4            0            6                 6  Kombi (Doğalgaz)  ...
#
#                           manzara otopark İnterkom depremyönetmeliğineuygun  \
# 0                               _       -      YOK                      YOK
# 1                               _       -      YOK                      YOK
# 2                               _       -      YOK                      YOK
# 3                               _       -      YOK                      YOK
# 4  Boğaz,Cadde,Dağ,Deniz,Doğa,Göl       -      VAR                      VAR
#
#   asansör Çocukoyunalanı giyinmeodası ebeveynbanyosu Ilan_ID  güncel_fiyat
# 0     YOK            YOK          VAR            YOK   64650           NaN
# 1     YOK            YOK          YOK            YOK   64651           NaN
# 2     YOK            YOK          YOK            YOK   64652           NaN
# 3     YOK            YOK          YOK            YOK   64653           NaN
# 4     VAR            VAR          VAR            VAR   64654           NaN
#
# [5 rows x 21 columns]

# %%
df = df.rename(columns = {
    'odasayısı': 'odasayisi',
    'brütm²': 'brutm2',
    'netm²': 'netm2',
    'binayaşı': 'binayasi',
    'bulunduğukat': 'bulundugukat',
    'binadakikatsayısı': 'binadakikatsayisi',
    'isıtmatipi': 'isitimatipi',
    'İnterkom': 'interkom',
    'depremyönetmeliğineuygun': 'depremyonetmeligineuygun',
    'asansör': 'asansor',
    'Çocukoyunalanı': 'cocukoyunalani',
    'güncel_fiyat': 'guncelfiyat',
})
df
# Out:
#             tarih                            path  odasayisi  brutm2  netm2  \
# 0      2020-04-20           İzmir/Konak/Güzelyalı  odasayisi   165.0  155.0
# 1      2020-04-20              İzmir/Ödemiş/İnönü  odasayisi   130.0  120.0
# 2      2020-04-20        İzmir/Karşıyaka/Örnekköy  odasayisi   182.0  153.0
# 3      2020-04-20              İzmir/Ödemiş/İnönü  odasayisi   130.0  120.0
# 4      2020-04-20     İstanbul/Beylikdüzü/Kavaklı  odasayisi   125.0  120.0
# ...           ...                             ...        ...     ...    ...
# 35122  2020-12-31              İzmir/Urla/İçmeler  odasayisi   200.0  180.0
# 35123  2020-12-31  İstanbul/Bağcılar/Fevzi Çakmak  odasayisi    85.0   65.0
# 35124  2020-12-31      İzmir/Seferihisar/Turabiye  odasayisi   125.0  120.0
# 35125  2020-12-31            İzmir/Foça/Fevzipaşa  odasayisi   427.0  245.0
# 35126  2020-12-31  İstanbul/Bağcılar/Fevzi Çakmak  odasayisi    85.0   65.0
#
#          emlaktipi     binayasi  bulundugukat binadakikatsayisi  \
# 0            Daire  31-35 arası             6                 7
# 1            Daire   6-10 arası             2                 2
# 2            Daire            0             7       10-20 arası
# 3            Daire   6-10 arası             2                 2
# 4            Daire            0             6                 6
# ...            ...          ...           ...               ...
# 35122        Villa  11-15 arası      Müstakil                 3
# 35123        Daire  21-25 arası  Yüksek Giriş                 5
# 35124        Daire            2             2                 4
# 35125  Müstakil Ev  40 ve üzeri      Müstakil                 2
# 35126        Daire  21-25 arası  Yüksek Giriş                 5
#
#             isitimatipi  ...                         manzara otopark interkom  \
# 0      Kombi (Doğalgaz)  ...                               _       -      YOK
# 1                 Klima  ...                               _       -      YOK
# 2         Yerden Isıtma  ...                               _       -      YOK
# 3                 Klima  ...                               _       -      YOK
# 4      Kombi (Doğalgaz)  ...  Boğaz,Cadde,Dağ,Deniz,Doğa,Göl       -      VAR
# ...                 ...  ...                             ...     ...      ...
# 35122             Klima  ...                               _       -      YOK
# 35123  Kombi (Doğalgaz)  ...                               _       -      YOK
# 35124  Kombi (Doğalgaz)  ...                               _       -      YOK
# 35125   Soba (Doğalgaz)  ...                               _     Yok      YOK
# 35126  Kombi (Doğalgaz)  ...                               _       -      YOK
#
#       depremyonetmeligineuygun asansor cocukoyunalani giyinmeodası  \
# 0                          YOK     YOK            YOK          VAR
# 1                          YOK     YOK            YOK          YOK
# 2                          YOK     YOK            YOK          YOK
# 3                          YOK     YOK            YOK          YOK
# 4                          VAR     VAR            VAR          VAR
# ...                        ...     ...            ...          ...
# 35122                      YOK     YOK            YOK          YOK
# 35123                      YOK     YOK            YOK          YOK
# 35124                      YOK     VAR            YOK          YOK
# 35125                      YOK     YOK            YOK          YOK
# 35126                      YOK     YOK            YOK          YOK
#
#       ebeveynbanyosu Ilan_ID  guncelfiyat
# 0                YOK   64650          NaN
# 1                YOK   64651          NaN
# 2                YOK   64652          NaN
# 3                YOK   64653          NaN
# 4                VAR   64654          NaN
# ...              ...     ...          ...
# 35122            YOK   99666          NaN
# 35123            YOK   99667          NaN
# 35124            YOK   99668          NaN
# 35125            YOK   99656          NaN
# 35126            YOK   99700          NaN
#
# [35127 rows x 21 columns]
